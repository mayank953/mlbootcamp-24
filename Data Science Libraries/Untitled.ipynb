# %%
import pandas as pd
data = pd.read_csv("/Users/admin/Github/mlbootcamp-24/Data Science Libraries/a/train.csv",header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 data = pd.read_csv(r"\Users\admin\Github\mlbootcamp-24\Data Science Libraries\train.csv",header=None)
#
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/admin/Github/mlbootcamp-24/Data Science Libraries'
