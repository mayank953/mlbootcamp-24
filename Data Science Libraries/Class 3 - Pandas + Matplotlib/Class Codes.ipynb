# %%
import pandas as pd
pd.set_option('display.max_columns', None)

titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.to_csv("titanic.csv",index=False)

# %%
titanic.head()

# Deleted first row
titanic.index = ['row' + str(i) for i in range(0,891)]

# %%
titanic.head()
# Out:
#       PassengerId  Survived  Pclass  \
# row0            1         0       3
# row1            2         1       1
# row2            3         1       3
# row3            4         1       1
# row4            5         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# row0                            Braund, Mr. Owen Harris    male  22.0      1
# row1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# row2                             Heikkinen, Miss. Laina  female  26.0      0
# row3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# row4                           Allen, Mr. William Henry    male  35.0      0
#
#       Parch            Ticket     Fare Cabin Embarked
# row0      0         A/5 21171   7.2500   NaN        S
# row1      0          PC 17599  71.2833   C85        C
# row2      0  STON/O2. 3101282   7.9250   NaN        S
# row3      0            113803  53.1000  C123        S
# ...

# %%
titanic.drop(titanic.index[:1],inplace=True)

# %%
titanic.head()
# Out:
#       PassengerId  Survived  Pclass  \
# row1            2         1       1
# row2            3         1       3
# row3            4         1       1
# row4            5         0       3
# row5            6         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# row1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# row2                             Heikkinen, Miss. Laina  female  26.0      0
# row3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# row4                           Allen, Mr. William Henry    male  35.0      0
# row5                                   Moran, Mr. James    male   NaN      0
#
#       Parch            Ticket     Fare Cabin Embarked
# row1      0          PC 17599  71.2833   C85        C
# row2      0  STON/O2. 3101282   7.9250   NaN        S
# row3      0            113803  53.1000  C123        S
# row4      0            373450   8.0500   NaN        S
# ...

# %%
titanic.iloc[0:6:2,0:2]
# Out:
#       PassengerId  Survived
# row1            2         1
# row3            4         1
# row5            6         0

# %%
titanic.loc[['row1','row3'],['Name','Fare']]
# Out:
#                                                    Name     Fare
# row1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# row3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000

# %%
titanic.drop(titanic.index[:1],inplace=True)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in titanic.columns:
    if(len(i)>8):
        print(i)
# Out:
# PassengerId

# %%
titanic.loc[titanic['Age']>35]
# Out:
#         PassengerId  Survived  Pclass  \
# row1              2         1       1
# row6              7         0       1
# row11            12         1       1
# row13            14         0       3
# row15            16         1       2
# ...             ...       ...     ...
# row865          866         1       2
# row871          872         1       1
# row873          874         0       3
# row879          880         1       1
# row885          886         0       3
#
#                                                      Name     Sex   Age  \
# row1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# row6                              McCarthy, Mr. Timothy J    male  54.0
# row11                            Bonnell, Miss. Elizabeth  female  58.0
# row13                         Andersson, Mr. Anders Johan    male  39.0
# row15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...

# %%
titanic.loc[titanic['Age'].notnull()]
# Out:
#         PassengerId  Survived  Pclass  \
# row1              2         1       1
# row2              3         1       3
# row3              4         1       1
# row4              5         0       3
# row6              7         0       1
# ...             ...       ...     ...
# row885          886         0       3
# row886          887         0       2
# row887          888         1       1
# row889          890         1       1
# row890          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# row1                                          mayank  female  38.0      1
# row2                          Heikkinen, Miss. Laina  female  26.0      0
# row3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# row4                        Allen, Mr. William Henry    male  35.0      0
# row6                         McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
class Student:
    
    def __init__(self):
        self.rollno = 50 # instance 
        
    def getRollNo(self): # Method
        return self.rollno

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890 entries, row1 to row890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  890 non-null    int64
#  1   Survived     890 non-null    int64
#  2   Pclass       890 non-null    int64
#  3   Name         890 non-null    object
#  4   Sex          890 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        890 non-null    int64
#  7   Parch        890 non-null    int64
#  8   Ticket       890 non-null    object
#  9   Fare         890 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     888 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.7+ KB

# %%
titanic.index,titanic.columns,titanic.shape
# Out:
# (Index(['row1', 'row2', 'row3', 'row4', 'row5', 'row6', 'row7', 'row8', 'row9',
#         'row10',
#         ...
#         'row881', 'row882', 'row883', 'row884', 'row885', 'row886', 'row887',
#         'row888', 'row889', 'row890'],
#        dtype='object', length=890),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'),
#  (890, 12))

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   890.000000  890.000000  890.000000  713.000000  890.000000
# mean    446.500000    0.384270    2.307865   29.709916    0.522472
# std     257.065167    0.486696    0.836220   14.533827    1.103247
# min       2.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.250000    0.000000    2.000000   20.000000    0.000000
# 50%     446.500000    0.000000    3.000000   28.000000    0.000000
# 75%     668.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  890.000000  890.000000
# mean     0.382022   32.232246
# std      0.806409   49.714317
# min      0.000000    0.000000
# 25%      0.000000    7.925000
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
def append_name(name):
    return "Sir/Mam " + str(name)

# %%
append_name("mayank")
# Out:
# 'Sir/Mam mayank'

# %%
titanic['Name'] = titanic['Name'].apply(append_name)

# %%
titanic['Name']['row1']  = "mayank"
# Out:
# /var/folders/xf/_6g19cpx1kb599118n7gc7yw0000gn/T/ipykernel_6952/3953428382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['Name']['row1']  = "mayank"

# %%
titanic.head(5)
# Out:
#       PassengerId  Survived  Pclass  \
# row1            2         1       1
# row2            3         1       3
# row3            4         1       1
# row4            5         0       3
# row5            6         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# row1                                     Sir/Mam mayank  female  38.0      1
# row2                     Sir/Mam Heikkinen, Miss. Laina  female  26.0      0
# row3  Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0      1
# row4                   Sir/Mam Allen, Mr. William Henry    male  35.0      0
# row5                           Sir/Mam Moran, Mr. James    male   NaN      0
#
#       Parch            Ticket     Fare Cabin Embarked
# row1      0          PC 17599  71.2833   C85        C
# row2      0  STON/O2. 3101282   7.9250   NaN        S
# row3      0            113803  53.1000  C123        S
# row4      0            373450   8.0500   NaN        S
# ...

# %%
# dataframe.apply(some_function)

# %%
def show_Name(row):
    print(row)

# %%
titanic['Name'].apply(show_Name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 titanic['Name']['row1'].apply(show_Name)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
titanic['Age'].apply(lambda age:age+5)
# Out:
# row1      43.0
# row2      31.0
# row3      40.0
# row4      40.0
# row5       NaN
#           ...
# row886    32.0
# row887    24.0
# row888     NaN
# row889    31.0
# row890    37.0
# Name: Age, Length: 890, dtype: float64

# %% [markdown]
# # Count

# %%
titanic.count()
# Out:
# PassengerId    890
# Survived       890
# Pclass         890
# Name           890
# Sex            890
# Age            713
# SibSp          890
# Parch          890
# Ticket         890
# Fare           890
# Cabin          204
# Embarked       888
# dtype: int64

# %%
titanic.head()
# Out:
#       PassengerId  Survived  Pclass  \
# row1            2         1       1
# row2            3         1       3
# row3            4         1       1
# row4            5         0       3
# row5            6         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# row1                                     Sir/Mam mayank  female  38.0      1
# row2                     Sir/Mam Heikkinen, Miss. Laina  female  26.0      0
# row3  Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0      1
# row4                   Sir/Mam Allen, Mr. William Henry    male  35.0      0
# row5                           Sir/Mam Moran, Mr. James    male   NaN      0
#
#       Parch            Ticket     Fare Cabin Embarked
# row1      0          PC 17599  71.2833   C85        C
# row2      0  STON/O2. 3101282   7.9250   NaN        S
# row3      0            113803  53.1000  C123        S
# row4      0            373450   8.0500   NaN        S
# ...

# %%
titanic.describe().T
# Out:
#              count        mean         std   min      25%       50%     75%  \
# PassengerId  890.0  446.500000  257.065167  2.00  224.250  446.5000  668.75
# Survived     890.0    0.384270    0.486696  0.00    0.000    0.0000    1.00
# Pclass       890.0    2.307865    0.836220  1.00    2.000    3.0000    3.00
# Age          713.0   29.709916   14.533827  0.42   20.000   28.0000   38.00
# SibSp        890.0    0.522472    1.103247  0.00    0.000    0.0000    1.00
# Parch        890.0    0.382022    0.806409  0.00    0.000    0.0000    0.00
# Fare         890.0   32.232246   49.714317  0.00    7.925   14.4542   31.00
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
titanic.concat(titanic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xf/_6g19cpx1kb599118n7gc7yw0000gn/T/ipykernel_6952/1573672859.py in ?()
# ----> 1 titanic.concat(titanic)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
Row1 = titanic.iloc[0,0:5]

# %%
Row1
# Out:
# PassengerId                 2
# Survived                    1
# Pclass                      1
# Name           Sir/Mam mayank
# Sex                    female
# Name: row1, dtype: object

# %%
pd.DataFrame(Row1).T
# Out:
#      PassengerId Survived Pclass            Name     Sex
# row1           2        1      1  Sir/Mam mayank  female

# %%
titanic._append(Row1)
# Out:
#         PassengerId  Survived  Pclass  \
# row1              2         1       1
# row2              3         1       3
# row3              4         1       1
# row4              5         0       3
# row5              6         0       3
# ...             ...       ...     ...
# row887          888         1       1
# row888          889         0       3
# row889          890         1       1
# row890          891         0       3
# row1              2         1       1
#
#                                                      Name     Sex   Age  \
# row1                                       Sir/Mam mayank  female  38.0
# row2                       Sir/Mam Heikkinen, Miss. Laina  female  26.0
# row3    Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0
# row4                     Sir/Mam Allen, Mr. William Henry    male  35.0
# row5                             Sir/Mam Moran, Mr. James    male   NaN
# ...

# %%
pd.concat([titanic,pd.DataFrame(Row1).T])
# Out:
#        PassengerId Survived Pclass  \
# row1             2        1      1
# row2             3        1      3
# row3             4        1      1
# row4             5        0      3
# row5             6        0      3
# ...            ...      ...    ...
# row887         888        1      1
# row888         889        0      3
# row889         890        1      1
# row890         891        0      3
# row1             2        1      1
#
#                                                      Name     Sex   Age  \
# row1                                       Sir/Mam mayank  female  38.0
# row2                       Sir/Mam Heikkinen, Miss. Laina  female  26.0
# row3    Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0
# row4                     Sir/Mam Allen, Mr. William Henry    male  35.0
# row5                             Sir/Mam Moran, Mr. James    male   NaN
# ...                                                   ...     ...   ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(titanic.dtypes)
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O')]

# %%
# sir, extract all the numerical/int column and apply .mean()

intCols = titanic.select_dtypes(include=['float64','int64'])
intCols.mean()
# Out:
# PassengerId    446.500000
# Survived         0.384270
# Pclass           2.307865
# Age             29.709916
# SibSp            0.522472
# Parch            0.382022
# Fare            32.232246
# dtype: float64

# %%
for i in titanic.columns:
    if titanic[i].dtype=="int64" or titanic[i].dtype=="float64":
        print(i,titanic[i].mean())
# Out:
# PassengerId 446.5
# Survived 0.3842696629213483
# Pclass 2.3078651685393257
# Age 29.70991584852735
# SibSp 0.5224719101123596
# Parch 0.38202247191011235
# Fare 32.232246404494376

# %%
df = pd.DataFrame([[1,2,3],[1,2,3],[7,8,9]],columns=['A','B','C'])

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  1  2  3
# 2  7  8  9

# %%
#0 is for row
# 1 is for column
df.sum(axis = 0)
# Out:
# A     8
# B    10
# C    12
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0     6
# 1    15
# 2    24
# dtype: int64

# %%
df.mean()
# Out:
# A    4.0
# B    5.0
# C    6.0
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    2.0
# 1    5.0
# 2    8.0
# dtype: float64

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  1  2  3
# 2  7  8  9

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 2  7  8  9

# %%
df.sort_index(inplace=True)

# %%
titanic.head()
# Out:
#       PassengerId  Survived  Pclass  \
# row1            2         1       1
# row2            3         1       3
# row3            4         1       1
# row4            5         0       3
# row5            6         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# row1                                     Sir/Mam mayank  female  38.0      1
# row2                     Sir/Mam Heikkinen, Miss. Laina  female  26.0      0
# row3  Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0      1
# row4                   Sir/Mam Allen, Mr. William Henry    male  35.0      0
# row5                           Sir/Mam Moran, Mr. James    male   NaN      0
#
#       Parch            Ticket     Fare Cabin Embarked
# row1      0          PC 17599  71.2833   C85        C
# row2      0  STON/O2. 3101282   7.9250   NaN        S
# row3      0            113803  53.1000  C123        S
# row4      0            373450   8.0500   NaN        S
# ...

# %%
titanic.index = ["row" + str(i) for i in range(890,0,-1)]

# %%
titanic.head()
# Out:
#         PassengerId  Survived  Pclass  \
# row890            2         1       1
# row889            3         1       3
# row888            4         1       1
# row887            5         0       3
# row886            6         0       3
#
#                                                      Name     Sex   Age  \
# row890                                     Sir/Mam mayank  female  38.0
# row889                     Sir/Mam Heikkinen, Miss. Laina  female  26.0
# row888  Sir/Mam Futrelle, Mrs. Jacques Heath (Lily May...  female  35.0
# row887                   Sir/Mam Allen, Mr. William Henry    male  35.0
# row886                           Sir/Mam Moran, Mr. James    male   NaN
#
#         SibSp  Parch            Ticket     Fare Cabin Embarked
# row890      1      0          PC 17599  71.2833   C85        C
# row889      0      0  STON/O2. 3101282   7.9250   NaN        S
# row888      1      0            113803  53.1000  C123        S
# ...

# %%
titanic.sort_index(inplace=True)

# %%
titanic.reset_index(drop=True,inplace=True)

# %%
titanic['Age']+=10000

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass                              Name   Sex  \
# 0          891         0       3       Sir/Mam Dooley, Mr. Patrick  male
# 1          882         0       3        Sir/Mam Markun, Mr. Johann  male
# 2          792         0       2       Sir/Mam Gaskell, Mr. Alfred  male
# 3          791         0       3  Sir/Mam Keane, Mr. Andrew "Andy"  male
# 4          790         0       1  Sir/Mam Guggenheim, Mr. Benjamin  male
#
#        Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 0  10037.0      0      0    370376   7.7500      NaN        Q
# 1  10038.0      0      0    349257   7.8958      NaN        S
# 2  10021.0      0      0    239865  26.0000      NaN        S
# 3      NaN      0      0     12460   7.7500      NaN        Q
# 4  10051.0      0      0  PC 17593  79.2000  B82 B84        C

# %%
# 0 for row
# 1 for column

# %%
titanic.drop('Age',axis=1)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0            891         0       3          Sir/Mam Dooley, Mr. Patrick
# 1            882         0       3           Sir/Mam Markun, Mr. Johann
# 2            792         0       2          Sir/Mam Gaskell, Mr. Alfred
# 3            791         0       3     Sir/Mam Keane, Mr. Andrew "Andy"
# 4            790         0       1     Sir/Mam Guggenheim, Mr. Benjamin
# ..           ...       ...     ...                                  ...
# 885          797         1       1  Sir/Mam Leader, Dr. Alice (Farnham)
# 886          796         0       2           Sir/Mam Otter, Mr. Richard
# 887          795         0       3        Sir/Mam Dantcheff, Mr. Ristiu
# 888          794         0       1     Sir/Mam Hoyt, Mr. William Fisher
# 889          793         0       3      Sir/Mam Sage, Miss. Stella Anna
#
#         Sex  SibSp  Parch    Ticket     Fare    Cabin Embarked
# ...

# %%
titanic.drop(4)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0            891         0       3          Sir/Mam Dooley, Mr. Patrick
# 1            882         0       3           Sir/Mam Markun, Mr. Johann
# 2            792         0       2          Sir/Mam Gaskell, Mr. Alfred
# 3            791         0       3     Sir/Mam Keane, Mr. Andrew "Andy"
# 5            789         1       3   Sir/Mam Dean, Master. Bertram Vere
# ..           ...       ...     ...                                  ...
# 885          797         1       1  Sir/Mam Leader, Dr. Alice (Farnham)
# 886          796         0       2           Sir/Mam Otter, Mr. Richard
# 887          795         0       3        Sir/Mam Dantcheff, Mr. Ristiu
# 888          794         0       1     Sir/Mam Hoyt, Mr. William Fisher
# 889          793         0       3      Sir/Mam Sage, Miss. Stella Anna
#
#         Sex      Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
titanic.count()
# Out:
# PassengerId    890
# Survived       890
# Pclass         890
# Name           890
# Sex            890
# Age            713
# SibSp          890
# Parch          890
# Ticket         890
# Fare           890
# Cabin          204
# Embarked       888
# dtype: int64

# %%
titanic.fillna(0).count()
# Out:
# PassengerId    890
# Survived       890
# Pclass         890
# Name           890
# Sex            890
# Age            890
# SibSp          890
# Parch          890
# Ticket         890
# Fare           890
# Cabin          890
# Embarked       890
# dtype: int64

# %%
titanic.dropna(inplace=True)

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 4           790         0       1
# 11          783         0       1
# 13          782         1       1
# 15          780         1       1
# 22          773         0       2
#
#                                                  Name     Sex      Age  SibSp  \
# 4                    Sir/Mam Guggenheim, Mr. Benjamin    male  10051.0      0
# 11                     Sir/Mam Long, Mr. Milton Clyde    male  10034.0      0
# 13  Sir/Mam Dick, Mrs. Albert Adrian (Vera Gillespie)  female  10022.0      1
# 15  Sir/Mam Robert, Mrs. Edward Scott (Elisabeth W...  female  10048.0      0
# 22                          Sir/Mam Mack, Mrs. (Mary)  female  10062.0      0
#
#     Parch       Ticket      Fare    Cabin Embarked
# 4       0     PC 17593   79.2000  B82 B84        C
# 11      0       113501   30.0000       D6        S
# 13      0        17474   57.0000      B20        S
# 15      1        24160  211.3375       B3        S
# ...

# %%
import datetime

datetime.datetime.now() # 10 min break
# Out:
# datetime.datetime(2024, 6, 1, 17, 2, 42, 973517)

# %% [markdown]
# # Pandas Series

# %%
titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
s1 = pd.Series([1,2,3],index=('row1','row2','row3'))
s2 = pd.Series([1,2,3],index=('row1','row2','row3'),name='Age')

# %%
s2
# Out:
# row1    1
# row2    2
# row3    3
# Name: Age, dtype: int64

# %%
s1['row1']
# Out:
# 1

# %%
pd.DataFrame(data = (s1,s2))
# Out:
#    row1  row2  row3
# 0     1     2     3
# 1     1     2     3

# %%
s1 = pd.Series([1,2,3],index=('row1','row2','row3'),name='one')
s1
# Out:
# row1    1
# row2    2
# row3    3
# Name: one, dtype: int64

# %%
s3 = pd.Series(list(range(5,895)),name='index5')

# %%
s3
# Out:
# 0        5
# 1        6
# 2        7
# 3        8
# 4        9
#       ...
# 885    890
# 886    891
# 887    892
# 888    893
# 889    894
# Name: index5, Length: 890, dtype: int64

# %%
pd.DataFrame(s3)
# Out:
#      index5
# 0         5
# 1         6
# 2         7
# 3         8
# 4         9
# ..      ...
# 885     890
# 886     891
# 887     892
# 888     893
# 889     894
#
# [890 rows x 1 columns]

# %%
pd.concat([titanic,(s3)],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 885          NaN       NaN     NaN
# 886          NaN       NaN     NaN
# 887          NaN       NaN     NaN
# 888          NaN       NaN     NaN
# 889          NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['index5'] = s3

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked   0    0    0    0  index5
# 0    0.0         A/5 21171   7.2500   NaN        S NaN  0.0  5.0  5.0     5.0
# 1    0.0          PC 17599  71.2833   C85        C NaN  1.0  6.0  6.0     6.0
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S NaN  2.0  7.0  7.0     7.0
# ...

# %% [markdown]
# # MatplotLib

# %%
import matplotlib as plt
