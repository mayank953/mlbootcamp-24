# %% [markdown]
# # Decision Tree Classification
#
# In this notebook, we'll implement the Decision Tree algorithm using `sklearn` and apply it to the Titanic dataset. We'll go through each step in detail, explaining the concepts and code to ensure a thorough understanding.

# %% [markdown]
# ## Importing Libraries
#
# First, we'll import the necessary libraries.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading the Titanic Dataset
#
# Let's load and inspect the Titanic dataset. We'll use the dataset from Seaborn's library.

# %%
# Loading the Titanic dataset
titanic = sns.load_dataset('titanic')

# Displaying the first few rows of the dataset
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Data Preprocessing
#
# We'll preprocess the data to handle missing values, encode categorical variables, and scale the features.

# %%
# Handling missing values
titanic = titanic.drop(['deck', 'embark_town', 'alive', 'who', 'adult_male', 'alone'], axis=1)  # Dropping columns with many missing values or irrelevant columns
titanic['age'].fillna(titanic['age'].median(), inplace=True)
titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)

# Encoding categorical variables
label_encoders = {}
categorical_features = ['sex', 'embarked', 'class']
for feature in categorical_features:
    label_encoders[feature] = LabelEncoder()
    titanic[feature] = label_encoders[feature].fit_transform(titanic[feature])

# Displaying the first few rows of the preprocessed dataset
print(titanic.head())
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class
# 0         0       3    1  22.0      1      0   7.2500         2      2
# 1         1       1    0  38.0      1      0  71.2833         0      0
# 2         1       3    0  26.0      0      0   7.9250         2      2
# 3         1       1    0  35.0      1      0  53.1000         2      0
# 4         0       3    1  35.0      0      0   8.0500         2      2
# /var/folders/xf/_6g19cpx1kb599118n7gc7yw0000gn/T/ipykernel_29321/398861314.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].fillna(titanic['age'].median(), inplace=True)
# /var/folders/xf/_6g19cpx1kb599118n7gc7yw0000gn/T/ipykernel_29321/398861314.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class'],
#       dtype='object')

# %% [markdown]
# ## Splitting the Dataset
#
# We'll split the dataset into training and testing sets to evaluate our Decision Tree model.

# %%
# Splitting the dataset into training and testing sets
X = titanic.drop(['survived'], axis=1).values
y = titanic['survived'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Training the Decision Tree
#
# Let's train our Decision Tree model on the Titanic dataset using `sklearn`'s `DecisionTreeClassifier`.

# %%
# Training the Decision Tree model
DT = DecisionTreeClassifier(random_state=42)
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
DT
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(DT, feature_names=titanic.drop(['survived'], axis=1).columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
# Out:
# [Text(0.3505743117559524, 0.9772727272727273, 'sex <= 0.5\ngini = 0.467\nsamples = 623\nvalue = [392, 231]\nclass = Not Survived'),
#  Text(0.15873015873015872, 0.9318181818181818, 'pclass <= 2.5\ngini = 0.396\nsamples = 213\nvalue = [58, 155]\nclass = Survived'),
#  Text(0.037698412698412696, 0.8863636363636364, 'age <= 2.5\ngini = 0.07\nsamples = 110\nvalue = [4, 106]\nclass = Survived'),
#  Text(0.015873015873015872, 0.8409090909090909, 'class <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.007936507936507936, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.023809523809523808, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.05952380952380952, 0.8409090909090909, 'fare <= 149.035\ngini = 0.054\nsamples = 108\nvalue = [3, 105]\nclass = Survived'),
#  Text(0.03968253968253968, 0.7954545454545454, 'age <= 49.5\ngini = 0.041\nsamples = 96\nvalue = [2, 94]\nclass = Survived'),
#  Text(0.023809523809523808, 0.75, 'fare <= 22.0\ngini = 0.024\nsamples = 84\nvalue = [1, 83]\nclass = Survived'),
#  Text(0.015873015873015872, 0.7045454545454546, 'fare <= 20.25\ngini = 0.083\nsamples = 23\nvalue = [1, 22]\nclass = Survived'),
#  Text(0.007936507936507936, 0.6590909090909091, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]\nclass = Survived'),
#  Text(0.023809523809523808, 0.6590909090909091, 'age <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.015873015873015872, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.031746031746031744, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.031746031746031744, 0.7045454545454546, 'gini = 0.0\nsamples = 61\nvalue = [0, 61]\nclass = Survived'),
#  Text(0.05555555555555555, 0.75, 'age <= 51.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.047619047619047616, 0.7045454545454546, 'fare <= 19.606\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.03968253968253968, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.05555555555555555, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.06349206349206349, 0.7045454545454546, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.07936507936507936, 0.7954545454545454, 'fare <= 152.506\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.07142857142857142, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.0873015873015873, 0.75, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Survived'),
#  Text(0.27976190476190477, 0.8863636363636364, 'fare <= 23.35\ngini = 0.499\nsamples = 103\nvalue = [54, 49]\nclass = Not Survived'),
#  Text(0.2261904761904762, 0.8409090909090909, 'age <= 36.5\ngini = 0.492\nsamples = 85\nvalue = [37, 48]\nclass = Survived'),
#  Text(0.21825396825396826, 0.7954545454545454, 'fare <= 15.373\ngini = 0.483\nsamples = 81\nvalue = [33, 48]\nclass = Survived'),
#  Text(0.1349206349206349, 0.75, 'fare <= 7.763\ngini = 0.499\nsamples = 57\nvalue = [27, 30]\nclass = Survived'),
#  Text(0.07936507936507936, 0.7045454545454546, 'parch <= 1.0\ngini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = Survived'),
#  Text(0.07142857142857142, 0.6590909090909091, 'fare <= 6.987\ngini = 0.32\nsamples = 20\nvalue = [4, 16]\nclass = Survived'),
#  Text(0.06349206349206349, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.07936507936507936, 0.6136363636363636, 'fare <= 7.59\ngini = 0.266\nsamples = 19\nvalue = [3, 16]\nclass = Survived'),
#  Text(0.07142857142857142, 0.5681818181818182, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.0873015873015873, 0.5681818181818182, 'fare <= 7.64\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = Survived'),
#  Text(0.07936507936507936, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.09523809523809523, 0.5227272727272727, 'fare <= 7.744\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Survived'),
#  Text(0.0873015873015873, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.10317460317460317, 0.4772727272727273, 'age <= 21.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.09523809523809523, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.1111111111111111, 0.4318181818181818, 'age <= 25.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.10317460317460317, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.11904761904761904, 0.38636363636363635, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Survived'),
#  Text(0.0873015873015873, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.19047619047619047, 0.7045454545454546, 'parch <= 0.5\ngini = 0.475\nsamples = 36\nvalue = [22, 14]\nclass = Not Survived'),
#  Text(0.14285714285714285, 0.6590909090909091, 'age <= 25.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]\nclass = Not Survived'),
#  Text(0.12698412698412698, 0.6136363636363636, 'embarked <= 1.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Not Survived'),
#  Text(0.11904761904761904, 0.5681818181818182, 'fare <= 11.242\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.1111111111111111, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.12698412698412698, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.1349206349206349, 0.5681818181818182, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not Survived'),
#  Text(0.15873015873015872, 0.6136363636363636, 'fare <= 7.888\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = Not Survived'),
#  Text(0.15079365079365079, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.16666666666666666, 0.5681818181818182, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Not Survived'),
#  Text(0.15873015873015872, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.1746031746031746, 0.5227272727272727, 'age <= 29.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not Survived'),
#  Text(0.16666666666666666, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not Survived'),
#  Text(0.18253968253968253, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.23809523809523808, 0.6590909090909091, 'age <= 27.5\ngini = 0.473\nsamples = 13\nvalue = [5, 8]\nclass = Survived'),
#  Text(0.2222222222222222, 0.6136363636363636, 'fare <= 13.935\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Survived'),
#  Text(0.21428571428571427, 0.5681818181818182, 'age <= 3.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Survived'),
#  Text(0.20634920634920634, 0.5227272727272727, 'fare <= 10.798\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.1984126984126984, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.21428571428571427, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.2222222222222222, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.23015873015873015, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.25396825396825395, 0.6136363636363636, 'fare <= 14.823\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not Survived'),
#  Text(0.24603174603174602, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.2619047619047619, 0.5681818181818182, 'age <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.25396825396825395, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.2698412698412698, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.30158730158730157, 0.75, 'embarked <= 1.5\ngini = 0.375\nsamples = 24\nvalue = [6, 18]\nclass = Survived'),
#  Text(0.29365079365079366, 0.7045454545454546, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.30952380952380953, 0.7045454545454546, 'fare <= 17.7\ngini = 0.48\nsamples = 15\nvalue = [6, 9]\nclass = Survived'),
#  Text(0.29365079365079366, 0.6590909090909091, 'age <= 27.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.2857142857142857, 0.6136363636363636, 'age <= 25.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.2777777777777778, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.29365079365079366, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.30158730158730157, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.3253968253968254, 0.6590909090909091, 'sibsp <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Not Survived'),
#  Text(0.31746031746031744, 0.6136363636363636, 'parch <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.30952380952380953, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.3253968253968254, 0.5681818181818182, 'parch <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.31746031746031744, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.3333333333333333, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.3333333333333333, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not Survived'),
#  Text(0.23412698412698413, 0.7954545454545454, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.3333333333333333, 0.8409090909090909, 'age <= 7.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = Not Survived'),
#  Text(0.3253968253968254, 0.7954545454545454, 'age <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.31746031746031744, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.3333333333333333, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3412698412698413, 0.7954545454545454, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Not Survived'),
#  Text(0.542418464781746, 0.9318181818181818, 'age <= 6.5\ngini = 0.302\nsamples = 410\nvalue = [334, 76]\nclass = Not Survived'),
#  Text(0.35714285714285715, 0.8863636363636364, 'sibsp <= 3.0\ngini = 0.42\nsamples = 20\nvalue = [6, 14]\nclass = Survived'),
#  Text(0.3492063492063492, 0.8409090909090909, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.36507936507936506, 0.8409090909090909, 'parch <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not Survived'),
#  Text(0.35714285714285715, 0.7954545454545454, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.373015873015873, 0.7954545454545454, 'fare <= 31.331\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.36507936507936506, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.38095238095238093, 0.75, 'fare <= 39.144\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.373015873015873, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3888888888888889, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.7276940724206349, 0.8863636363636364, 'fare <= 52.277\ngini = 0.267\nsamples = 390\nvalue = [328.0, 62.0]\nclass = Not Survived'),
#  Text(0.5327690972222222, 0.8409090909090909, 'age <= 77.0\ngini = 0.227\nsamples = 344\nvalue = [299, 45]\nclass = Not Survived'),
#  Text(0.5248325892857143, 0.7954545454545454, 'pclass <= 1.5\ngini = 0.224\nsamples = 343\nvalue = [299, 44]\nclass = Not Survived'),
#  Text(0.42063492063492064, 0.75, 'fare <= 30.75\ngini = 0.357\nsamples = 43\nvalue = [33, 10]\nclass = Not Survived'),
#  Text(0.40476190476190477, 0.7045454545454546, 'fare <= 26.144\ngini = 0.444\nsamples = 27\nvalue = [18, 9]\nclass = Not Survived'),
#  Text(0.3968253968253968, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not Survived'),
#  Text(0.4126984126984127, 0.6590909090909091, 'age <= 53.0\ngini = 0.49\nsamples = 21\nvalue = [12, 9]\nclass = Not Survived'),
#  Text(0.40476190476190477, 0.6136363636363636, 'age <= 39.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]\nclass = Survived'),
#  Text(0.3968253968253968, 0.5681818181818182, 'fare <= 30.25\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Not Survived'),
#  Text(0.3888888888888889, 0.5227272727272727, 'fare <= 26.419\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Not Survived'),
#  Text(0.38095238095238093, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3968253968253968, 0.4772727272727273, 'fare <= 28.725\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Not Survived'),
#  Text(0.3888888888888889, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.40476190476190477, 0.4318181818181818, 'age <= 28.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.3968253968253968, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4126984126984127, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.40476190476190477, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4126984126984127, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.42063492063492064, 0.6136363636363636, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not Survived'),
#  Text(0.4365079365079365, 0.7045454545454546, 'age <= 55.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Not Survived'),
#  Text(0.42857142857142855, 0.6590909090909091, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not Survived'),
#  Text(0.4444444444444444, 0.6590909090909091, 'embarked <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.4365079365079365, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4523809523809524, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.6290302579365079, 0.75, 'age <= 13.0\ngini = 0.201\nsamples = 300\nvalue = [266, 34]\nclass = Not Survived'),
#  Text(0.5143849206349206, 0.7045454545454546, 'sibsp <= 2.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Not Survived'),
#  Text(0.5064484126984127, 0.6590909090909091, 'sibsp <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.49851190476190477, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.5143849206349206, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.5223214285714286, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not Survived'),
#  Text(0.7436755952380952, 0.7045454545454546, 'age <= 32.25\ngini = 0.191\nsamples = 290\nvalue = [259, 31]\nclass = Not Survived'),
#  Text(0.6460813492063492, 0.6590909090909091, 'age <= 31.5\ngini = 0.217\nsamples = 210\nvalue = [184, 26]\nclass = Not Survived'),
#  Text(0.5302579365079365, 0.6136363636363636, 'embarked <= 0.5\ngini = 0.195\nsamples = 201\nvalue = [179, 22]\nclass = Not Survived'),
#  Text(0.4444444444444444, 0.5681818181818182, 'age <= 22.5\ngini = 0.337\nsamples = 28\nvalue = [22, 6]\nclass = Not Survived'),
#  Text(0.42063492063492064, 0.5227272727272727, 'fare <= 5.619\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.4126984126984127, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.42857142857142855, 0.4772727272727273, 'age <= 17.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.42063492063492064, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.4365079365079365, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.46825396825396826, 0.5227272727272727, 'sibsp <= 0.5\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = Not Survived'),
#  Text(0.4603174603174603, 0.4772727272727273, 'fare <= 16.919\ngini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Not Survived'),
#  Text(0.4523809523809524, 0.4318181818181818, 'fare <= 7.562\ngini = 0.278\nsamples = 18\nvalue = [15, 3]\nclass = Not Survived'),
#  Text(0.42857142857142855, 0.38636363636363635, 'fare <= 7.227\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not Survived'),
#  Text(0.42063492063492064, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.4365079365079365, 0.3409090909090909, 'age <= 28.25\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Not Survived'),
#  Text(0.42857142857142855, 0.29545454545454547, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not Survived'),
#  Text(0.4444444444444444, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.47619047619047616, 0.38636363636363635, 'age <= 28.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not Survived'),
#  Text(0.46825396825396826, 0.3409090909090909, 'fare <= 10.879\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not Survived'),
#  Text(0.4603174603174603, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.47619047619047616, 0.29545454545454547, 'fare <= 14.454\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.46825396825396826, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.48412698412698413, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.48412698412698413, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.46825396825396826, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.47619047619047616, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not Survived'),
#  Text(0.6160714285714286, 0.5681818181818182, 'fare <= 7.798\ngini = 0.168\nsamples = 173\nvalue = [157, 16]\nclass = Not Survived'),
#  Text(0.5396825396825397, 0.5227272727272727, 'fare <= 7.746\ngini = 0.278\nsamples = 48\nvalue = [40, 8]\nclass = Not Survived'),
#  Text(0.5238095238095238, 0.4772727272727273, 'fare <= 7.196\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = Not Survived'),
#  Text(0.5158730158730159, 0.4318181818181818, 'fare <= 7.133\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not Survived'),
#  Text(0.5079365079365079, 0.38636363636363635, 'fare <= 3.248\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Not Survived'),
#  Text(0.5, 0.3409090909090909, 'pclass <= 2.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not Survived'),
#  Text(0.49206349206349204, 0.29545454545454547, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not Survived'),
#  Text(0.5079365079365079, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5158730158730159, 0.3409090909090909, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not Survived'),
#  Text(0.5238095238095238, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5317460317460317, 0.4318181818181818, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Not Survived'),
#  Text(0.5555555555555556, 0.4772727272727273, 'age <= 20.0\ngini = 0.386\nsamples = 23\nvalue = [17, 6]\nclass = Not Survived'),
#  Text(0.5476190476190477, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.5634920634920635, 0.4318181818181818, 'age <= 21.5\ngini = 0.432\nsamples = 19\nvalue = [13, 6]\nclass = Not Survived'),
#  Text(0.5555555555555556, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5714285714285714, 0.38636363636363635, 'age <= 24.5\ngini = 0.401\nsamples = 18\nvalue = [13, 5]\nclass = Not Survived'),
#  Text(0.5634920634920635, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.5793650793650794, 0.3409090909090909, 'age <= 25.5\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Not Survived'),
#  Text(0.5714285714285714, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5873015873015873, 0.29545454545454547, 'age <= 30.0\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Not Survived'),
#  Text(0.5793650793650794, 0.25, 'age <= 28.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = Not Survived'),
#  Text(0.5714285714285714, 0.20454545454545456, 'fare <= 7.763\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Not Survived'),
#  Text(0.5555555555555556, 0.1590909090909091, 'sibsp <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not Survived'),
#  Text(0.5476190476190477, 0.11363636363636363, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not Survived'),
#  Text(0.5634920634920635, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.5873015873015873, 0.1590909090909091, 'age <= 26.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not Survived'),
#  Text(0.5793650793650794, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.5952380952380952, 0.11363636363636363, 'age <= 27.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.5873015873015873, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6031746031746031, 0.06818181818181818, 'fare <= 7.785\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.5952380952380952, 0.022727272727272728, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.6111111111111112, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.5873015873015873, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5952380952380952, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.6924603174603174, 0.5227272727272727, 'age <= 30.5\ngini = 0.12\nsamples = 125\nvalue = [117, 8]\nclass = Not Survived'),
#  Text(0.6626984126984127, 0.4772727272727273, 'age <= 20.5\ngini = 0.107\nsamples = 123\nvalue = [116, 7]\nclass = Not Survived'),
#  Text(0.626984126984127, 0.4318181818181818, 'fare <= 8.175\ngini = 0.219\nsamples = 32\nvalue = [28, 4]\nclass = Not Survived'),
#  Text(0.6031746031746031, 0.38636363636363635, 'fare <= 7.91\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not Survived'),
#  Text(0.5952380952380952, 0.3409090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not Survived'),
#  Text(0.6111111111111112, 0.3409090909090909, 'fare <= 7.988\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Not Survived'),
#  Text(0.6031746031746031, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6190476190476191, 0.29545454545454547, 'age <= 19.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not Survived'),
#  Text(0.6111111111111112, 0.25, 'age <= 17.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.6031746031746031, 0.20454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.6190476190476191, 0.20454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.626984126984127, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.6507936507936508, 0.38636363636363635, 'age <= 18.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Not Survived'),
#  Text(0.6428571428571429, 0.3409090909090909, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Not Survived'),
#  Text(0.6587301587301587, 0.3409090909090909, 'class <= 1.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Not Survived'),
#  Text(0.6507936507936508, 0.29545454545454547, 'fare <= 11.75\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not Survived'),
#  Text(0.6428571428571429, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.6587301587301587, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.6666666666666666, 0.29545454545454547, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.6984126984126984, 0.4318181818181818, 'sibsp <= 1.5\ngini = 0.064\nsamples = 91\nvalue = [88, 3]\nclass = Not Survived'),
#  Text(0.6825396825396826, 0.38636363636363635, 'fare <= 8.081\ngini = 0.045\nsamples = 86\nvalue = [84, 2]\nclass = Not Survived'),
#  Text(0.6746031746031746, 0.3409090909090909, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]\nclass = Not Survived'),
#  Text(0.6904761904761905, 0.3409090909090909, 'fare <= 8.388\ngini = 0.081\nsamples = 47\nvalue = [45, 2]\nclass = Not Survived'),
#  Text(0.6825396825396826, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6984126984126984, 0.29545454545454547, 'class <= 1.5\ngini = 0.043\nsamples = 46\nvalue = [45, 1]\nclass = Not Survived'),
#  Text(0.6904761904761905, 0.25, 'age <= 27.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Not Survived'),
#  Text(0.6825396825396826, 0.20454545454545456, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not Survived'),
#  Text(0.6984126984126984, 0.20454545454545456, 'age <= 28.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Not Survived'),
#  Text(0.6904761904761905, 0.1590909090909091, 'fare <= 13.25\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not Survived'),
#  Text(0.6825396825396826, 0.11363636363636363, 'fare <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.6746031746031746, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.6904761904761905, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6984126984126984, 0.11363636363636363, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.7063492063492064, 0.1590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not Survived'),
#  Text(0.7063492063492064, 0.25, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Not Survived'),
#  Text(0.7142857142857143, 0.38636363636363635, 'embarked <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not Survived'),
#  Text(0.7063492063492064, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7222222222222222, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.7222222222222222, 0.4772727272727273, 'parch <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.7142857142857143, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7301587301587301, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.7619047619047619, 0.6136363636363636, 'fare <= 20.925\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = Not Survived'),
#  Text(0.753968253968254, 0.5681818181818182, 'fare <= 8.206\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Not Survived'),
#  Text(0.746031746031746, 0.5227272727272727, 'embarked <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Not Survived'),
#  Text(0.7380952380952381, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.753968253968254, 0.4772727272727273, 'fare <= 7.875\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.746031746031746, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7619047619047619, 0.4318181818181818, 'fare <= 7.91\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.753968253968254, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.7698412698412699, 0.38636363636363635, 'fare <= 7.988\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7619047619047619, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.7777777777777778, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7619047619047619, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.7698412698412699, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8412698412698413, 0.6590909090909091, 'age <= 61.0\ngini = 0.117\nsamples = 80\nvalue = [75, 5]\nclass = Not Survived'),
#  Text(0.8253968253968254, 0.6136363636363636, 'fare <= 13.25\ngini = 0.1\nsamples = 76\nvalue = [72, 4]\nclass = Not Survived'),
#  Text(0.8174603174603174, 0.5681818181818182, 'fare <= 12.762\ngini = 0.145\nsamples = 51\nvalue = [47, 4]\nclass = Not Survived'),
#  Text(0.7936507936507936, 0.5227272727272727, 'fare <= 7.91\ngini = 0.089\nsamples = 43\nvalue = [41, 2]\nclass = Not Survived'),
#  Text(0.7857142857142857, 0.4772727272727273, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Not Survived'),
#  Text(0.8015873015873016, 0.4772727272727273, 'fare <= 7.988\ngini = 0.18\nsamples = 20\nvalue = [18, 2]\nclass = Not Survived'),
#  Text(0.7936507936507936, 0.4318181818181818, 'age <= 38.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.7857142857142857, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.8015873015873016, 0.38636363636363635, 'age <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7936507936507936, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.8095238095238095, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8095238095238095, 0.4318181818181818, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Not Survived'),
#  Text(0.8412698412698413, 0.5227272727272727, 'age <= 45.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Not Survived'),
#  Text(0.8333333333333334, 0.4772727272727273, 'age <= 36.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not Survived'),
#  Text(0.8253968253968254, 0.4318181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.8412698412698413, 0.4318181818181818, 'age <= 40.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.8333333333333334, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.8492063492063492, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.8492063492063492, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not Survived'),
#  Text(0.8333333333333334, 0.5681818181818182, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Not Survived'),
#  Text(0.8571428571428571, 0.6136363636363636, 'age <= 66.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not Survived'),
#  Text(0.8492063492063492, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8650793650793651, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not Survived'),
#  Text(0.5407056051587301, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9226190476190477, 0.8409090909090909, 'fare <= 59.087\ngini = 0.466\nsamples = 46\nvalue = [29, 17]\nclass = Not Survived'),
#  Text(0.8888888888888888, 0.7954545454545454, 'age <= 22.0\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Survived'),
#  Text(0.8809523809523809, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.8968253968253969, 0.75, 'age <= 43.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = Survived'),
#  Text(0.8888888888888888, 0.7045454545454546, 'pclass <= 2.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = Survived'),
#  Text(0.8809523809523809, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.8968253968253969, 0.6590909090909091, 'age <= 30.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.8888888888888888, 0.6136363636363636, 'age <= 27.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not Survived'),
#  Text(0.8809523809523809, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8968253968253969, 0.5681818181818182, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.9047619047619048, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9047619047619048, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.9563492063492064, 0.7954545454545454, 'embarked <= 0.5\ngini = 0.389\nsamples = 34\nvalue = [25, 9]\nclass = Not Survived'),
#  Text(0.9365079365079365, 0.75, 'fare <= 77.965\ngini = 0.49\nsamples = 14\nvalue = [6, 8]\nclass = Survived'),
#  Text(0.9285714285714286, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9444444444444444, 0.7045454545454546, 'fare <= 369.927\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = Not Survived'),
#  Text(0.9365079365079365, 0.6590909090909091, 'fare <= 99.99\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Not Survived'),
#  Text(0.9206349206349206, 0.6136363636363636, 'fare <= 85.638\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.9126984126984127, 0.5681818181818182, 'parch <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not Survived'),
#  Text(0.9047619047619048, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not Survived'),
#  Text(0.9206349206349206, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9285714285714286, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9523809523809523, 0.6136363636363636, 'age <= 17.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not Survived'),
#  Text(0.9444444444444444, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9603174603174603, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not Survived'),
#  Text(0.9523809523809523, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9761904761904762, 0.75, 'fare <= 86.737\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Not Survived'),
#  Text(0.9682539682539683, 0.7045454545454546, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Not Survived'),
#  Text(0.9841269841269841, 0.7045454545454546, 'parch <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not Survived'),
#  Text(0.9761904761904762, 0.6590909090909091, 'sibsp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not Survived'),
#  Text(0.9682539682539683, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9841269841269841, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not Survived'),
#  Text(0.9920634920634921, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not Survived')]

# %% [markdown]
# ## Evaluating the Model
#
# We'll evaluate the model using accuracy, confusion matrix, and classification report.

# %%
# Making predictions on the test set
y_pred = tree.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('\nConfusion Matrix:')
print(conf_matrix)
print('\nClassification Report:')
print(class_report)
# Out:
# Accuracy: 0.746268656716418
#
# Confusion Matrix:
# [[124  33]
#  [ 35  76]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78       157
#            1       0.70      0.68      0.69       111
#
#     accuracy                           0.75       268
#    macro avg       0.74      0.74      0.74       268
# weighted avg       0.75      0.75      0.75       268

# %% [markdown]
# ## Hyperparameter Tuning
#
# We'll use `GridSearchCV` to find the best hyperparameters for our Decision Tree model.

# %%
# Defining the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 2, 4, 6, 8, 10, 12],
    'min_samples_split': [2, 5, 10, 20]
}

# Performing grid search with cross-validation
grid_search = GridSearchCV(estimator=tree, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)

# Displaying the best parameters and best score
print(f'Best Parameters: {grid_search.best_params_}')
print(f'Best Score: {grid_search.best_score_}')
# Out:
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# Best Parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 2}
# Best Score: 0.8154451612903226

# %% [markdown]
# ## Visualizing the Decision Tree
#
# We'll visualize the decision tree to understand how it makes decisions.

# %%
from sklearn.tree import plot_tree

# Visualizing the decision tree
best_tree = grid_search.best_estimator_
plt.figure(figsize=(20, 10))
plot_tree(best_tree, feature_names=titanic.drop(['survived'], axis=1).columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook, we implemented the Decision Tree algorithm using `sklearn` and applied it to the Titanic dataset. We visualized the dataset, preprocessed the data, trained the model, evaluated its performance, and performed hyperparameter tuning. Finally, we visualized the decision tree to understand how it makes decisions.
