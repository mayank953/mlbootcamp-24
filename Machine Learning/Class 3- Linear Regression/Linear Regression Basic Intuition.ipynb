# %% [markdown]
# # Simple Linear Regression Example
#
# In this example, we'll demonstrate how to perform simple linear regression using scikit-learn.
# We'll create a dataset with two variables: study hours and the score of the student.
# Then, we'll use linear regression to find the best-fit line for the data.
# Finally, we'll visualize the data points and the regression line to understand the intuition behind linear regression.

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Define the dataset
study_hours = np.array([3, 5, 2, 7, 4, 6, 1, 3, 5, 4]).reshape(-1, 1) # X 
scores = np.array([75, 82, 69, 88, 78, 85, 62, 72, 80, 76]) # y

# %%
plt.scatter(study_hours,scores)
plt.xlabel('Study Hours')
plt.ylabel('Scores')
plt.show()

# %%
# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(study_hours, scores)
# Out:
# LinearRegression()

# %%
# Get the slope and intercept of the regression line
slope = model.coef_[0]
intercept = model.intercept_
slope, intercept
# Out:
# (4.166666666666666, 60.03333333333334)

# %%
slope * 8 + intercept
# Out:
# 93.36666666666667

# %%
model.predict(np.array(5).reshape(1,-1))
# Out:
# array([80.86666667])

# %%
# Visualize the data points and regression line
plt.scatter(study_hours, scores, color='blue', label='Data Points')



plt.plot(study_hours, model.predict(study_hours), color='red', label='Regression Line')


plt.plot(np.array([0,1]).reshape(1,-1), np.array([0,1]).reshape(1,-1), color='black', label='Slope Line')



plt.title('Linear Regression Example')
plt.xlabel('Study Hours')
plt.ylabel('Score')


plt.legend()




plt.show()

# %%
#model.score(study_hours,scores)

# %%
class MyOwnLR():
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):

        n = X_train.shape[0]

        mnum = 0
        mden = 0

        x_bar = X_train.mean()
        y_bar = y_train.mean()
        
        for i in range(n):
            mnum = mnum + (( X_train[i] - x_bar)*(y_train[i] - y_bar))
            mden = mden + ((X_train[i] - x_bar)*(X_train[i] - x_bar))

        self.m = mnum/mden
        self.b = y_bar - self.m*x_bar

        print(self.m)
        print(self.b)
        

    def predict(self,X_test):
        return self.m * X_test + self.b

# %%
myLR = MyOwnLR()

# %%
myLR.fit(study_hours,scores)
# Out:
# [4.16666667]
# [60.03333333]
